# %% [markdown]
# ### Assignment 5

# %% [markdown]
# **Q.1.** Write a formula which can be dragged right and down to generate a multiplication table.
#
# (Generate Multiplication Table.xlsx)

# %% [markdown]
# **Solution :-**
#
# Using below mention formula we can generate multiplication table.
#
# formula = $A2 * B$1
#
# ![Excel%20Assignment%205.jpg](attachment:Excel%20Assignment%205.jpg)
