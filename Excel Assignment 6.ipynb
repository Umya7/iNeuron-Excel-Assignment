# %% [markdown]
# ### Assignment 6

# %% [markdown]
# **Q.1.** 1. Fill in the table of 2016 sales by month by store using only 1 SUMIFS Formula (Many Sales Sample Data)

# %% [markdown]
# **Solution 1:-**

# %%
FORMULA =SUMIFS($C$2:$C$150000,$B$2:$B$150000,$E16,$A$2:$A$150000,F$15)

# %% [markdown]
# ![E_Assignment%206.1.jpg](attachment:E_Assignment%206.1.jpg)

# %% [markdown]
# **Q.2.** 2. Fill in the table of 2016 sales by month by store using only 1 SUMPRODUCT Formula (Many Sales Sample Data)

# %% [markdown]
# **Solution 2:-**

# %%
FORMULA =SUMPRODUCT($C$2:$C$150000*($B$2:$B$150000=$E3)*($A$2:$A$150000=F$2))

# %% [markdown]
# ![E_Assignment%206.2.jpg](attachment:E_Assignment%206.2.jpg)

# %% [markdown]
# **Q.3.** Create a Pivot Table that only shoes the 2016 sales by month by store. (Many Sales Sample Data)

# %% [markdown]
# **Solution 3:-**
#
# ![E_Assignment%206.3.jpg](attachment:E_Assignment%206.3.jpg)
