# %% [markdown]
# ### Assignment 7

# %% [markdown]
# **Q.1.** Write a formula which returns "Palindrome" or Not "Palindrome" for a given word in (palindrome.xslx)

# %% [markdown]
# **Solution :-**
#
# Formula : IF(SUMPRODUCT(--(MID(SUBSTITUTE(B5," ",""),ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B5," ","")))),1)=MID(SUBSTITUTE(B5," ",""),LEN(SUBSTITUTE(B5," ",""))+1-ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B5," ","")))),1)))=LEN(SUBSTITUTE(B5," ","")),"Palindrome","Not Palindrome")
#
# ![E_Assignment%207.jpg](attachment:E_Assignment%207.jpg)
