# %% [markdown]
# ### Assignment 3

# %% [markdown]
# **Q.1.** Find duplicates and show the count.

# %% [markdown]
# **Solution :-**
#
# Using the below shown formula find duplicates & count.
#
# =LEFT(SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2),FIND("%",SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2))-1)
#
# =IF(COUNTIF(F1:F2,F2)=1,COUNTIF(F:F,F2),"")
#
# ![E_Assignment%203.jpg](attachment:E_Assignment%203.jpg)
